# %%
import os
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import sys
import os

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(""))))
from src.pre_process.feature_add import FeatureAddition
from src.pre_process.feature_duplicate import FeatureDuplication

# %%
BASE_PATH = r'C:\Users\USER\OneDrive\문서\GitHub\level2-competitiveds-recsys-06\data\processed'
data = pd.read_csv(os.path.join(BASE_PATH, 'v4_baek+recent+rank.csv'))
# train_data = pd.read_csv(os.path.join(BASE_PATH, 'train.csv'))
# test_data = pd.read_csv(os.path.join(BASE_PATH, 'test.csv'))
# sample_submission = pd.read_csv(os.path.join(BASE_PATH, 'sample_submission.csv'))

# %%
sample_submission = pd.read_csv(os.path.join(BASE_PATH, 'sample_submission.csv'))

# %% [markdown]
# ---

# %%
data
# Out:
#           index   area_m2  contract_year_month  contract_day  contract_type  \
# 0             0   84.9981               201906            25              2
# 1             1   84.9981               202003            26              2
# 2             2   84.9981               202003            28              2
# 3             3   59.3400               201907            15              2
# 4             4   59.8100               201904            12              2
# ...         ...       ...                  ...           ...            ...
# 1951395  150167  115.5101               202402            27              0
# 1951396  150168  142.8738               202403             2              0
# 1951397  150169  142.8738               202403            16              1
# 1951398  150170  114.9285               202403            22              1
# 1951399  150171  115.5101               202403            22              1
#
#          floor  built_year   latitude   longitude  age  ...  \
# 0            9        2019  37.054314  127.045216    0  ...
# 1           20        2019  37.054314  127.045216    1  ...
# 2            8        2019  37.054314  127.045216    1  ...
# 3            1        1986  36.964647  127.055847   33  ...
# 4            6        1995  36.972390  127.084514   24  ...
# ...        ...         ...        ...         ...  ...  ...
# 1951395     17        2010  37.528394  126.659398   14  ...
# 1951396      4        2010  37.528394  126.659398   14  ...
# 1951397     13        2010  37.528394  126.659398   14  ...
# 1951398      2        2010  37.528394  126.659398   14  ...
# 1951399      7        2010  37.528394  126.659398   14  ...
#
#          has_high_school_within_1km nearest_park_distance  \
# 0                                 1            498.618918
# 1                                 1            498.618918
# 2                                 1            498.618918
# 3                                 1            169.839678
# 4                                 0            382.401815
# ...                             ...                   ...
# 1951395                           1            398.113485
# 1951396                           1            398.113485
# 1951397                           1            398.113485
# 1951398                           1            398.113485
# 1951399                           1            398.113485
#
#          nearest_park_within_500.0m  has_park_within_500.0m  apt_deposit_rank  \
# 0                                 1                       1              7683
# 1                                 1                       1              7683
# 2                                 1                       1              7683
# 3                                 3                       1             18366
# 4                                 1                       1             18369
# ...                             ...                     ...               ...
# 1951395                           1                       1              6088
# 1951396                           1                       1              6088
# 1951397                           1                       1              6088
# 1951398                           1                       1              6088
# 1951399                           1                       1              6088
#
#          apt_area_deposit_rank  original_index  recent_deposit  interest_rate  \
# 0                        29300               0             NaN           1.78
# 1                        29300               1         17000.0           1.26
# 2                        29300               2         23000.0           1.26
# 3                        58901               3             NaN           1.68
# 4                        58863               4             NaN           1.85
# ...                        ...             ...             ...            ...
# 1951395                  25360          150167         37000.0           3.62
# 1951396                  17911          150168         43000.0           3.59
# 1951397                  17911          150169         43000.0           3.59
# 1951398                  24128          150170         32500.0           3.59
# 1951399                  25360          150171         37000.0           3.59
#
#          diff_interest_rate
# 0                     -0.07
# 1                     -0.17
# 2                     -0.17
# 3                     -0.10
# 4                     -0.09
# ...                     ...
# 1951395               -0.04
# 1951396               -0.03
# 1951397               -0.03
# 1951398               -0.03
# 1951399               -0.03
#
# [1951400 rows x 41 columns]

# %%
data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'nearest_park_distance',
#        'nearest_park_within_500.0m', 'has_park_within_500.0m',
#        'apt_deposit_rank', 'apt_area_deposit_rank', 'original_index',
#        'recent_deposit', 'interest_rate', 'diff_interest_rate'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # 추가 EDA

# %%
# contract_type one-hot encoding
data = pd.get_dummies(data, columns=['contract_type'], prefix='contract')

# %%
data.drop(columns='contract_2', inplace=True)

# %%
data
# Out:
#           index   area_m2  contract_year_month  contract_day  floor  \
# 0             0   84.9981               201906            25      9
# 1             1   84.9981               202003            26     20
# 2             2   84.9981               202003            28      8
# 3             3   59.3400               201907            15      1
# 4             4   59.8100               201904            12      6
# ...         ...       ...                  ...           ...    ...
# 1951395  150167  115.5101               202402            27     17
# 1951396  150168  142.8738               202403             2      4
# 1951397  150169  142.8738               202403            16     13
# 1951398  150170  114.9285               202403            22      2
# 1951399  150171  115.5101               202403            22      7
#
#          built_year   latitude   longitude  age  deposit  ...  \
# 0              2019  37.054314  127.045216    0  17000.0  ...
# 1              2019  37.054314  127.045216    1  23000.0  ...
# 2              2019  37.054314  127.045216    1  23000.0  ...
# 3              1986  36.964647  127.055847   33   5000.0  ...
# 4              1995  36.972390  127.084514   24   1800.0  ...
# ...             ...        ...         ...  ...      ...  ...
# 1951395        2010  37.528394  126.659398   14      NaN  ...
# 1951396        2010  37.528394  126.659398   14      NaN  ...
# 1951397        2010  37.528394  126.659398   14      NaN  ...
# 1951398        2010  37.528394  126.659398   14      NaN  ...
# 1951399        2010  37.528394  126.659398   14      NaN  ...
#
#         nearest_park_within_500.0m  has_park_within_500.0m  apt_deposit_rank  \
# 0                                1                       1              7683
# 1                                1                       1              7683
# 2                                1                       1              7683
# 3                                3                       1             18366
# 4                                1                       1             18369
# ...                            ...                     ...               ...
# 1951395                          1                       1              6088
# 1951396                          1                       1              6088
# 1951397                          1                       1              6088
# 1951398                          1                       1              6088
# 1951399                          1                       1              6088
#
#          apt_area_deposit_rank  original_index  recent_deposit  interest_rate  \
# 0                        29300               0             NaN           1.78
# 1                        29300               1         17000.0           1.26
# 2                        29300               2         23000.0           1.26
# 3                        58901               3             NaN           1.68
# 4                        58863               4             NaN           1.85
# ...                        ...             ...             ...            ...
# 1951395                  25360          150167         37000.0           3.62
# 1951396                  17911          150168         43000.0           3.59
# 1951397                  17911          150169         43000.0           3.59
# 1951398                  24128          150170         32500.0           3.59
# 1951399                  25360          150171         37000.0           3.59
#
#          diff_interest_rate  contract_0  contract_1
# 0                     -0.07       False       False
# 1                     -0.17       False       False
# 2                     -0.17       False       False
# 3                     -0.10       False       False
# 4                     -0.09       False       False
# ...                     ...         ...         ...
# 1951395               -0.04        True       False
# 1951396               -0.03        True       False
# 1951397               -0.03       False        True
# 1951398               -0.03       False        True
# 1951399               -0.03       False        True
#
# [1951400 rows x 42 columns]

# %%
data['contract_year_month'] = data['contract_year_month'].astype(str)

# 'contract_day'를 두 자리로 맞추기 위한 처리
data['contract_day'] = data['contract_day'].apply(lambda x: f"{x:02d}")

# 날짜 형식으로 결합
data['contract_date'] = pd.to_datetime(data['contract_year_month'] + data['contract_day'], format='%Y%m%d')

# %%
data
# Out:
#           index   area_m2 contract_year_month contract_day  floor  built_year  \
# 0             0   84.9981              201906           25      9        2019
# 1             1   84.9981              202003           26     20        2019
# 2             2   84.9981              202003           28      8        2019
# 3             3   59.3400              201907           15      1        1986
# 4             4   59.8100              201904           12      6        1995
# ...         ...       ...                 ...          ...    ...         ...
# 1951395  150167  115.5101              202402           27     17        2010
# 1951396  150168  142.8738              202403           02      4        2010
# 1951397  150169  142.8738              202403           16     13        2010
# 1951398  150170  114.9285              202403           22      2        2010
# 1951399  150171  115.5101              202403           22      7        2010
#
#           latitude   longitude  age  deposit  ... has_park_within_500.0m  \
# 0        37.054314  127.045216    0  17000.0  ...                      1
# 1        37.054314  127.045216    1  23000.0  ...                      1
# 2        37.054314  127.045216    1  23000.0  ...                      1
# 3        36.964647  127.055847   33   5000.0  ...                      1
# 4        36.972390  127.084514   24   1800.0  ...                      1
# ...            ...         ...  ...      ...  ...                    ...
# 1951395  37.528394  126.659398   14      NaN  ...                      1
# 1951396  37.528394  126.659398   14      NaN  ...                      1
# 1951397  37.528394  126.659398   14      NaN  ...                      1
# 1951398  37.528394  126.659398   14      NaN  ...                      1
# 1951399  37.528394  126.659398   14      NaN  ...                      1
#
#          apt_deposit_rank  apt_area_deposit_rank  original_index  \
# 0                    7683                  29300               0
# 1                    7683                  29300               1
# 2                    7683                  29300               2
# 3                   18366                  58901               3
# 4                   18369                  58863               4
# ...                   ...                    ...             ...
# 1951395              6088                  25360          150167
# 1951396              6088                  17911          150168
# 1951397              6088                  17911          150169
# 1951398              6088                  24128          150170
# 1951399              6088                  25360          150171
#
#          recent_deposit  interest_rate  diff_interest_rate  contract_0  \
# 0                   NaN           1.78               -0.07       False
# 1               17000.0           1.26               -0.17       False
# 2               23000.0           1.26               -0.17       False
# 3                   NaN           1.68               -0.10       False
# 4                   NaN           1.85               -0.09       False
# ...                 ...            ...                 ...         ...
# 1951395         37000.0           3.62               -0.04        True
# 1951396         43000.0           3.59               -0.03        True
# 1951397         43000.0           3.59               -0.03       False
# 1951398         32500.0           3.59               -0.03       False
# 1951399         37000.0           3.59               -0.03       False
#
#          contract_1  contract_date
# 0             False     2019-06-25
# 1             False     2020-03-26
# 2             False     2020-03-28
# 3             False     2019-07-15
# 4             False     2019-04-12
# ...             ...            ...
# 1951395       False     2024-02-27
# 1951396       False     2024-03-02
# 1951397        True     2024-03-16
# 1951398        True     2024-03-22
# 1951399        True     2024-03-22
#
# [1951400 rows x 43 columns]

# %%
data['contract_date_numeric'] = data['contract_date'].dt.strftime('%Y%m%d').astype(int)

# %%
data
# Out:
#           index   area_m2 contract_year_month contract_day  floor  built_year  \
# 0             0   84.9981              201906           25      9        2019
# 1             1   84.9981              202003           26     20        2019
# 2             2   84.9981              202003           28      8        2019
# 3             3   59.3400              201907           15      1        1986
# 4             4   59.8100              201904           12      6        1995
# ...         ...       ...                 ...          ...    ...         ...
# 1951395  150167  115.5101              202402           27     17        2010
# 1951396  150168  142.8738              202403           02      4        2010
# 1951397  150169  142.8738              202403           16     13        2010
# 1951398  150170  114.9285              202403           22      2        2010
# 1951399  150171  115.5101              202403           22      7        2010
#
#           latitude   longitude  age  deposit  ... apt_deposit_rank  \
# 0        37.054314  127.045216    0  17000.0  ...             7683
# 1        37.054314  127.045216    1  23000.0  ...             7683
# 2        37.054314  127.045216    1  23000.0  ...             7683
# 3        36.964647  127.055847   33   5000.0  ...            18366
# 4        36.972390  127.084514   24   1800.0  ...            18369
# ...            ...         ...  ...      ...  ...              ...
# 1951395  37.528394  126.659398   14      NaN  ...             6088
# 1951396  37.528394  126.659398   14      NaN  ...             6088
# 1951397  37.528394  126.659398   14      NaN  ...             6088
# 1951398  37.528394  126.659398   14      NaN  ...             6088
# 1951399  37.528394  126.659398   14      NaN  ...             6088
#
#          apt_area_deposit_rank  original_index  recent_deposit  interest_rate  \
# 0                        29300               0             NaN           1.78
# 1                        29300               1         17000.0           1.26
# 2                        29300               2         23000.0           1.26
# 3                        58901               3             NaN           1.68
# 4                        58863               4             NaN           1.85
# ...                        ...             ...             ...            ...
# 1951395                  25360          150167         37000.0           3.62
# 1951396                  17911          150168         43000.0           3.59
# 1951397                  17911          150169         43000.0           3.59
# 1951398                  24128          150170         32500.0           3.59
# 1951399                  25360          150171         37000.0           3.59
#
#          diff_interest_rate  contract_0  contract_1  contract_date  \
# 0                     -0.07       False       False     2019-06-25
# 1                     -0.17       False       False     2020-03-26
# 2                     -0.17       False       False     2020-03-28
# 3                     -0.10       False       False     2019-07-15
# 4                     -0.09       False       False     2019-04-12
# ...                     ...         ...         ...            ...
# 1951395               -0.04        True       False     2024-02-27
# 1951396               -0.03        True       False     2024-03-02
# 1951397               -0.03       False        True     2024-03-16
# 1951398               -0.03       False        True     2024-03-22
# 1951399               -0.03       False        True     2024-03-22
#
#          contract_date_numeric
# 0                     20190625
# 1                     20200326
# 2                     20200328
# 3                     20190715
# 4                     20190412
# ...                        ...
# 1951395               20240227
# 1951396               20240302
# 1951397               20240316
# 1951398               20240322
# 1951399               20240322
#
# [1951400 rows x 44 columns]

# %%
data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day', 'floor',
#        'built_year', 'latitude', 'longitude', 'age', 'deposit', '_type',
#        'apt_idx', 'area', 'area_price', 'area_m2_price', 'grid_id',
#        'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'nearest_park_distance',
#        'nearest_park_within_500.0m', 'has_park_within_500.0m',
#        'apt_deposit_rank', 'apt_area_deposit_rank', 'original_index',
#        'recent_deposit', 'interest_rate', 'diff_interest_rate', 'contract_0',
#        'contract_1', 'contract_date', 'contract_date_numeric'],
#       dtype='object')

# %%
data[(data['age'] < 0) & (data['_type'] == 'test')]
# Out:
# Empty DataFrame
# Columns: [index, area_m2, contract_year_month, contract_day, floor, built_year, latitude, longitude, age, deposit, _type, apt_idx, area, area_price, area_m2_price, grid_id, nearest_subway_distance, nearest_subway_idx, num_subway_within_1km, category_interchange_within_1km, num_subway_within_500m, category_interchange_within_500m, nearest_elementary_school_distance, nearest_elementary_school_within_1km, has_elementary_school_within_1km, nearest_middle_school_distance, nearest_middle_school_within_1km, has_middle_school_within_1km, nearest_high_school_distance, nearest_high_school_within_1km, has_high_school_within_1km, nearest_park_distance, nearest_park_within_500.0m, has_park_within_500.0m, apt_deposit_rank, apt_area_deposit_rank, original_index, recent_deposit, interest_rate, diff_interest_rate, contract_0, contract_1, contract_date, contract_date_numeric]
# Index: []
#
# [0 rows x 44 columns]

# %%
data = pd.get_dummies(data, columns=['category_interchange_within_1km'], prefix='interchange')

# %%
data.drop(columns=['interchange_0', 'interchange_1'], inplace=True)

# %%
data
# Out:
#           index   area_m2 contract_year_month contract_day  floor  built_year  \
# 0             0   84.9981              201906           25      9        2019
# 1             1   84.9981              202003           26     20        2019
# 2             2   84.9981              202003           28      8        2019
# 3             3   59.3400              201907           15      1        1986
# 4             4   59.8100              201904           12      6        1995
# ...         ...       ...                 ...          ...    ...         ...
# 1951395  150167  115.5101              202402           27     17        2010
# 1951396  150168  142.8738              202403           02      4        2010
# 1951397  150169  142.8738              202403           16     13        2010
# 1951398  150170  114.9285              202403           22      2        2010
# 1951399  150171  115.5101              202403           22      7        2010
#
#           latitude   longitude  age  deposit  ... original_index  \
# 0        37.054314  127.045216    0  17000.0  ...              0
# 1        37.054314  127.045216    1  23000.0  ...              1
# 2        37.054314  127.045216    1  23000.0  ...              2
# 3        36.964647  127.055847   33   5000.0  ...              3
# 4        36.972390  127.084514   24   1800.0  ...              4
# ...            ...         ...  ...      ...  ...            ...
# 1951395  37.528394  126.659398   14      NaN  ...         150167
# 1951396  37.528394  126.659398   14      NaN  ...         150168
# 1951397  37.528394  126.659398   14      NaN  ...         150169
# 1951398  37.528394  126.659398   14      NaN  ...         150170
# 1951399  37.528394  126.659398   14      NaN  ...         150171
#
#          recent_deposit  interest_rate  diff_interest_rate  contract_0  \
# 0                   NaN           1.78               -0.07       False
# 1               17000.0           1.26               -0.17       False
# 2               23000.0           1.26               -0.17       False
# 3                   NaN           1.68               -0.10       False
# 4                   NaN           1.85               -0.09       False
# ...                 ...            ...                 ...         ...
# 1951395         37000.0           3.62               -0.04        True
# 1951396         43000.0           3.59               -0.03        True
# 1951397         43000.0           3.59               -0.03       False
# 1951398         32500.0           3.59               -0.03       False
# 1951399         37000.0           3.59               -0.03       False
#
#          contract_1  contract_date  contract_date_numeric  interchange_2  \
# 0             False     2019-06-25               20190625          False
# 1             False     2020-03-26               20200326          False
# 2             False     2020-03-28               20200328          False
# 3             False     2019-07-15               20190715          False
# 4             False     2019-04-12               20190412          False
# ...             ...            ...                    ...            ...
# 1951395       False     2024-02-27               20240227          False
# 1951396       False     2024-03-02               20240302          False
# 1951397        True     2024-03-16               20240316          False
# 1951398        True     2024-03-22               20240322          False
# 1951399        True     2024-03-22               20240322          False
#
#          apt_floor_deposit_rank
# 0                         97941
# 1                        113270
# 2                        100261
# 3                        191078
# 4                        192552
# ...                         ...
# 1951395                   77448
# 1951396                   60621
# 1951397                   85567
# 1951398                   75423
# 1951399                   80672
#
# [1951400 rows x 45 columns]

# %%
grouped_floor_df = (
    data.groupby(["latitude", "longitude", "floor"])["deposit"]
    .agg(["mean", "count"])
    .reset_index()
)
# 전체 deposit의 평균 계산 (NaN 제외)
overall_mean = data["deposit"].mean()
# NaN 그룹 처리: deposit이 모두 NaN인 그룹의 평균을 전체 평균으로 설정
grouped_floor_df["mean"] = grouped_floor_df["mean"].fillna(overall_mean)
# mean을 기준으로 정렬
grouped_floor_df = grouped_floor_df.sort_values(by="mean", ascending=False)
# apt_area_deposit_rank 부여
grouped_floor_df["apt_floor_deposit_rank"] = range(1, len(grouped_floor_df) + 1)
# 원래 데이터프레임에 apt_area_deposit_rank 병합
data = data.merge(
    grouped_floor_df[
        ["latitude", "longitude", "floor", "apt_floor_deposit_rank"]
    ],
    on=["latitude", "longitude", "floor"],
    how="left",
)

# %%
data['apt_floor_deposit_rank'].max()
# Out:
# np.int64(192636)

# %%
grouped_age_df = (
    data.groupby(["latitude", "longitude", "age"])["deposit"]
    .agg(["mean", "count"])
    .reset_index()
)
# 전체 deposit의 평균 계산 (NaN 제외)
overall_mean = data["deposit"].mean()
# NaN 그룹 처리: deposit이 모두 NaN인 그룹의 평균을 전체 평균으로 설정
grouped_age_df["mean"] = grouped_floor_df["mean"].fillna(overall_mean)
# mean을 기준으로 정렬
grouped_age_df = grouped_age_df.sort_values(by="mean", ascending=False)
# apt_area_deposit_rank 부여
grouped_age_df["apt_age_deposit_rank"] = range(1, len(grouped_age_df) + 1)
# 원래 데이터프레임에 apt_area_deposit_rank 병합
data = data.merge(
    grouped_age_df[
        ["latitude", "longitude", "age", "apt_age_deposit_rank"]
    ],
    on=["latitude", "longitude", "age"],
    how="left",
)

# %%
data['apt_age_deposit_rank'].max()
# Out:
# np.int64(84936)

# %% [markdown]
# ---

# %%
train_data = data[data['_type'] == 'train']
test_data = data[data['_type'] == 'test']

# %%
column_needed = [
    # 'index', '_type', 'area_price', 'area_m2_price', 'original_index', 'contract_type','contract_year_month', 'contract_day',
    'area_m2', 'contract_date_numeric',
    'floor', 'built_year', 'latitude', 'longitude', 'age',
    'contract_0', 'contract_1',
    'deposit',
    'apt_idx',
    'area',
    'grid_id',
    'nearest_subway_distance',
    'nearest_subway_idx',
    # 'num_subway_within_1km',
    # 'category_interchange_within_1km',
    # 'num_subway_within_500m', 
    # 'category_interchange_within_500m',
    'nearest_elementary_school_distance',
    # 'nearest_elementary_school_within_1km',
    # 'has_elementary_school_within_1km',
    'nearest_middle_school_distance',
    # 'nearest_middle_school_within_1km',
    # 'has_middle_school_within_1km',
    'nearest_high_school_distance',
    # 'nearest_high_school_within_1km',
    # 'has_high_school_within_1km',
    'nearest_park_distance',
    # 'nearest_park_within_500.0m',
    # 'has_park_within_500.0m',
    'apt_deposit_rank', 'apt_area_deposit_rank',
    'recent_deposit',
    'interchange_2',
    'apt_floor_deposit_rank',
    # 'apt_age_deposit_rank',
    # 'interest_rate', 
    # 'diff_interest_rate',
]
test_column_needed = [
    # 'index', '_type', 'area_price', 'area_m2_price', 'original_index','deposit', 'contract_type','contract_year_month', 'contract_day',
    'area_m2', 'contract_date_numeric',
    'floor', 'built_year', 'latitude', 'longitude', 'age',
    'contract_0', 'contract_1',
    'apt_idx',
    'area',
    'grid_id',
    'nearest_subway_distance',
    'nearest_subway_idx',
    # 'num_subway_within_1km',
    # 'category_interchange_within_1km',
    # 'num_subway_within_500m', 
    # 'category_interchange_within_500m',
    'nearest_elementary_school_distance',
    # 'nearest_elementary_school_within_1km',
    # 'has_elementary_school_within_1km',
    'nearest_middle_school_distance',
    # 'nearest_middle_school_within_1km',
    # 'has_middle_school_within_1km',
    'nearest_high_school_distance',
    # 'nearest_high_school_within_1km',
    # 'has_high_school_within_1km',
    'nearest_park_distance',
    # 'nearest_park_within_500.0m',
    # 'has_park_within_500.0m',
    'apt_deposit_rank', 'apt_area_deposit_rank',
    'recent_deposit',
    'interchange_2',
    'apt_floor_deposit_rank',
    # 'apt_age_deposit_rank',
    # 'interest_rate', 
    # 'diff_interest_rate',
]
train_df = train_data[column_needed]
test_df = test_data[test_column_needed]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# # 학습에 사용할 특징 열
# feature_columns = [col for col in data.columns if col not in ['deposit', '_type', 'index']]
# 학습 및 테스트 데이터 준비
X_train = train_df.drop(columns=['deposit'])
y_train = train_df['deposit']
X_test = test_df.copy()
# 학습 데이터를 검증용으로 분할
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.2,
                                                                          random_state=42)
# XGBoost를 위한 DMatrix 생성
dtrain = xgb.DMatrix(X_train_split, label=y_train_split)
dval = xgb.DMatrix(X_val_split, label=y_val_split)
dtest = xgb.DMatrix(X_test)
# XGBoost 파라미터 설정
params = {
    'objective': 'reg:absoluteerror',
    'eval_metric': 'mae',
    'max_depth': 6,
    'eta': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}
# 모델 학습
evals = [(dtrain, 'train'), (dval, 'eval')]
model = xgb.train(params, dtrain, num_boost_round=500, early_stopping_rounds=50, evals=evals, verbose_eval=10)
# 테스트 세트에 대한 예측
y_pred = model.predict(dtest)
# Out:
# [0]	train-mae:16507.17539	eval-mae:16508.41712
# [10]	train-mae:11263.40680	eval-mae:11266.54844
# [20]	train-mae:8102.02081	eval-mae:8101.13086
# [30]	train-mae:6266.23366	eval-mae:6258.99375
# [40]	train-mae:5266.42898	eval-mae:5256.63410
# [50]	train-mae:4717.76170	eval-mae:4709.54461
# [60]	train-mae:4442.03688	eval-mae:4436.14382
# [70]	train-mae:4293.33222	eval-mae:4289.34274
# [80]	train-mae:4209.00925	eval-mae:4206.39583
# [90]	train-mae:4163.16486	eval-mae:4161.62842
# [100]	train-mae:4126.61132	eval-mae:4126.10043
# [110]	train-mae:4101.99039	eval-mae:4102.41553
# [120]	train-mae:4075.50878	eval-mae:4076.74140
# [130]	train-mae:4049.31033	eval-mae:4051.50100
# [140]	train-mae:4031.08294	eval-mae:4033.81210
# [150]	train-mae:4012.98370	eval-mae:4016.91465
# [160]	train-mae:4001.21375	eval-mae:4005.68985
# [170]	train-mae:3987.38207	eval-mae:3992.72382
# [180]	train-mae:3976.01193	eval-mae:3981.75539
# [190]	train-mae:3962.43217	eval-mae:3968.79241
# [200]	train-mae:3949.61878	eval-mae:3956.84451
# [210]	train-mae:3940.18796	eval-mae:3947.93390
# [220]	train-mae:3930.58645	eval-mae:3938.99845
# [230]	train-mae:3921.95453	eval-mae:3930.75765
# [240]	train-mae:3914.95417	eval-mae:3924.25134
# [250]	train-mae:3904.49863	eval-mae:3914.48462
# [260]	train-mae:3897.93976	eval-mae:3908.42136
# [270]	train-mae:3890.37175	eval-mae:3901.34805
# [280]	train-mae:3882.62367	eval-mae:3894.09310
# [290]	train-mae:3875.00242	eval-mae:3886.94087
# [300]	train-mae:3867.10016	eval-mae:3879.35068
# [310]	train-mae:3861.08183	eval-mae:3873.70070
# [320]	train-mae:3855.61227	eval-mae:3868.77876
# [330]	train-mae:3850.90297	eval-mae:3864.54587
# [340]	train-mae:3847.79377	eval-mae:3861.79093
# [350]	train-mae:3841.32287	eval-mae:3855.81312
# [360]	train-mae:3837.71708	eval-mae:3852.51271
# [370]	train-mae:3831.86313	eval-mae:3847.14215
# [380]	train-mae:3827.98480	eval-mae:3843.54596
# [390]	train-mae:3822.79856	eval-mae:3838.95725
# [400]	train-mae:3818.08726	eval-mae:3834.62151
# [410]	train-mae:3813.41901	eval-mae:3830.44166
# [420]	train-mae:3809.03109	eval-mae:3826.69781
# [430]	train-mae:3805.87296	eval-mae:3823.87156
# [440]	train-mae:3802.01784	eval-mae:3820.38731
# [450]	train-mae:3797.12006	eval-mae:3815.86533
# [460]	train-mae:3793.26557	eval-mae:3812.30819
# [470]	train-mae:3790.53684	eval-mae:3809.98670
# [480]	train-mae:3786.49471	eval-mae:3806.46470
# [490]	train-mae:3783.24310	eval-mae:3803.47279
# [499]	train-mae:3778.90625	eval-mae:3799.81658

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Feature Importance
# 피처 중요도 추출
feature_importance = model.get_fscore()
# 피처 중요도를 DataFrame으로 변환
importance_df = pd.DataFrame(feature_importance.items(), columns=['Feature', 'Importance'])
# 중요도 순으로 정렬
importance_df = importance_df.sort_values(by='Importance', ascending=False)
# 시각화
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.show()

# %%
y_pred
# Out:
# array([22055.064 ,  7631.2983,  6959.3774, ..., 43753.32  , 37024.883 ,
#        37223.137 ], dtype=float32)

# %%
sample_submission['deposit'] = y_pred
sample_submission
# Out:
#          index       deposit
# 0            0  22055.064453
# 1            1   7631.298340
# 2            2   6959.377441
# 3            3   6970.602539
# 4            4   7039.619141
# ...        ...           ...
# 150167  150167  37629.339844
# 150168  150168  45417.039062
# 150169  150169  43753.320312
# 150170  150170  37024.882812
# 150171  150171  37223.136719
#
# [150172 rows x 2 columns]

# %%
sample_submission.describe()
# Out:
#               index        deposit
# count  150172.00000  150172.000000
# mean    75085.50000   38953.000000
# std     43351.06665   23654.078125
# min         0.00000    2487.443848
# 25%     37542.75000   23210.509766
# 50%     75085.50000   33793.919922
# 75%    112628.25000   48197.175781
# max    150171.00000  354945.000000

# %%
sample_submission.to_csv('v4_add(apt_floor_rank).csv', index=False)

# %% [markdown]
# ---

# %%
dt = xgb.DMatrix(X_train)
x_pred = model.predict(dt)

# %%
x_pred.mean()
# Out:
# np.float32(38021.207)

# %%
train_data['deposit_xgb'] = x_pred
test_data['deposit_xgb'] = y_pred
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6332\167302861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['deposit_xgb'] = x_pred
# C:\Users\USER\AppData\Local\Temp\ipykernel_6332\167302861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['deposit_xgb'] = y_pred

# %%
train_data.drop(columns=['deposit_xgboost'], inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6332\4262335724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop(columns=['deposit_xgboost'], inplace=True)

# %%
train_data
# Out:
#            index   area_m2 contract_year_month contract_day  floor  \
# 0              0   84.9981              201906           25      9
# 1              1   84.9981              202003           26     20
# 2              2   84.9981              202003           28      8
# 3              3   59.3400              201907           15      1
# 4              4   59.8100              201904           12      6
# ...          ...       ...                 ...          ...    ...
# 1801223  1801223  114.8126              202311           25      5
# 1801224  1801224  101.9088              202311           28      6
# 1801225  1801225  114.7900              202312           03     19
# 1801226  1801226  101.9088              202312           04     15
# 1801227  1801227  114.7900              202312           16     10
#
#          built_year   latitude   longitude  age  deposit  ... interest_rate  \
# 0              2019  37.054314  127.045216    0  17000.0  ...          1.78
# 1              2019  37.054314  127.045216    1  23000.0  ...          1.26
# 2              2019  37.054314  127.045216    1  23000.0  ...          1.26
# 3              1986  36.964647  127.055847   33   5000.0  ...          1.68
# 4              1995  36.972390  127.084514   24   1800.0  ...          1.85
# ...             ...        ...         ...  ...      ...  ...           ...
# 1801223        2010  37.528394  126.659398   13  39000.0  ...          4.00
# 1801224        2010  37.528394  126.659398   13  38000.0  ...          4.00
# 1801225        2010  37.528394  126.659398   13  37000.0  ...          3.84
# 1801226        2010  37.528394  126.659398   13  34400.0  ...          3.84
# 1801227        2010  37.528394  126.659398   13  45000.0  ...          3.84
#
#          diff_interest_rate  contract_0  contract_1  contract_date  \
# 0                     -0.07       False       False     2019-06-25
# 1                     -0.17       False       False     2020-03-26
# 2                     -0.17       False       False     2020-03-28
# 3                     -0.10       False       False     2019-07-15
# 4                     -0.09       False       False     2019-04-12
# ...                     ...         ...         ...            ...
# 1801223                0.03        True       False     2023-11-25
# 1801224                0.03        True       False     2023-11-28
# 1801225               -0.16        True       False     2023-12-03
# 1801226               -0.16       False        True     2023-12-04
# 1801227               -0.16        True       False     2023-12-16
#
#          contract_date_numeric  interchange_2  apt_floor_deposit_rank  \
# 0                     20190625          False                   97941
# 1                     20200326          False                  113270
# 2                     20200328          False                  100261
# 3                     20190715          False                  191078
# 4                     20190412          False                  192552
# ...                        ...            ...                     ...
# 1801223               20231125          False                   89159
# 1801224               20231128          False                   82542
# 1801225               20231203          False                   56452
# 1801226               20231204          False                   77673
# 1801227               20231216          False                   57736
#
#          apt_age_deposit_rank   deposit_xgb
# 0                       68180  25370.437500
# 1                       45336  25423.611328
# 2                       45336  26568.945312
# 3                       83873   3870.588135
# 4                       84882   3102.130127
# ...                       ...           ...
# 1801223                 41273  34872.437500
# 1801224                 41273  35268.730469
# 1801225                 41273  34787.164062
# 1801226                 41273  37370.910156
# 1801227                 41273  36365.343750
#
# [1801228 rows x 47 columns]

# %%
test_data
# Out:
#           index   area_m2 contract_year_month contract_day  floor  built_year  \
# 1801228       0   84.9610              202404           12     14        2016
# 1801229       1   59.9000              202404           13      4        1997
# 1801230       2   39.2700              202404           29      5        1990
# 1801231       3   39.2700              202405           03      1        1990
# 1801232       4   46.9800              202406           02      4        1990
# ...         ...       ...                 ...          ...    ...         ...
# 1951395  150167  115.5101              202402           27     17        2010
# 1951396  150168  142.8738              202403           02      4        2010
# 1951397  150169  142.8738              202403           16     13        2010
# 1951398  150170  114.9285              202403           22      2        2010
# 1951399  150171  115.5101              202403           22      7        2010
#
#           latitude   longitude  age  deposit  ... interest_rate  \
# 1801228  36.965423  127.048779    8      NaN  ...          3.54
# 1801229  36.963105  127.040678   27      NaN  ...          3.54
# 1801230  36.957089  127.047449   34      NaN  ...          3.54
# 1801231  36.957089  127.047449   34      NaN  ...          3.56
# 1801232  36.957089  127.047449   34      NaN  ...          3.56
# ...            ...         ...  ...      ...  ...           ...
# 1951395  37.528394  126.659398   14      NaN  ...          3.62
# 1951396  37.528394  126.659398   14      NaN  ...          3.59
# 1951397  37.528394  126.659398   14      NaN  ...          3.59
# 1951398  37.528394  126.659398   14      NaN  ...          3.59
# 1951399  37.528394  126.659398   14      NaN  ...          3.59
#
#          diff_interest_rate  contract_0  contract_1  contract_date  \
# 1801228               -0.05       False        True     2024-04-12
# 1801229               -0.05        True       False     2024-04-13
# 1801230               -0.05        True       False     2024-04-29
# 1801231                0.02        True       False     2024-05-03
# 1801232                0.00        True       False     2024-06-02
# ...                     ...         ...         ...            ...
# 1951395               -0.04        True       False     2024-02-27
# 1951396               -0.03        True       False     2024-03-02
# 1951397               -0.03       False        True     2024-03-16
# 1951398               -0.03       False        True     2024-03-22
# 1951399               -0.03       False        True     2024-03-22
#
#          contract_date_numeric  interchange_2  apt_floor_deposit_rank  \
# 1801228               20240412          False                  152134
# 1801229               20240413          False                  189676
# 1801230               20240429          False                  190974
# 1801231               20240503          False                  191242
# 1801232               20240602          False                  191607
# ...                        ...            ...                     ...
# 1951395               20240227          False                   77448
# 1951396               20240302          False                   60621
# 1951397               20240316          False                   85567
# 1951398               20240322          False                   75423
# 1951399               20240322          False                   80672
#
#          apt_age_deposit_rank   deposit_xgb
# 1801228                 26098  22055.064453
# 1801229                 25913   7631.298340
# 1801230                 25529   6959.377441
# 1801231                 25529   6970.602539
# 1801232                 25529   7039.619141
# ...                       ...           ...
# 1951395                 26467  37629.339844
# 1951396                 26467  45417.039062
# 1951397                 26467  43753.320312
# 1951398                 26467  37024.882812
# 1951399                 26467  37223.136719
#
# [150172 rows x 47 columns]

# %%
column_needed = [
    # 'index', '_type', 'area_price', 'area_m2_price', 'original_index', 'contract_type','contract_year_month', 'contract_day',
    'area_m2', 'contract_date_numeric',
    'floor', 'built_year', 'latitude', 'longitude', 'age',
    'contract_0', 'contract_1',
    'deposit',
    'apt_idx',
    'area',
    'grid_id',
    'nearest_subway_distance',
    'nearest_subway_idx',
    # 'num_subway_within_1km',
    # 'category_interchange_within_1km',
    # 'num_subway_within_500m', 
    # 'category_interchange_within_500m',
    'nearest_elementary_school_distance',
    # 'nearest_elementary_school_within_1km',
    # 'has_elementary_school_within_1km',
    'nearest_middle_school_distance',
    # 'nearest_middle_school_within_1km',
    # 'has_middle_school_within_1km',
    'nearest_high_school_distance',
    # 'nearest_high_school_within_1km',
    # 'has_high_school_within_1km',
    'nearest_park_distance',
    # 'nearest_park_within_500.0m',
    # 'has_park_within_500.0m',
    'apt_deposit_rank', 'apt_area_deposit_rank',
    'recent_deposit',
    'interchange_2',
    'apt_floor_deposit_rank',
    'deposit_xgb',
    # 'apt_age_deposit_rank',
    # 'interest_rate', 
    # 'diff_interest_rate',
]
test_column_needed = [
    # 'index', '_type', 'area_price', 'area_m2_price', 'original_index','deposit', 'contract_type','contract_year_month', 'contract_day',
    'area_m2', 'contract_date_numeric',
    'floor', 'built_year', 'latitude', 'longitude', 'age',
    'contract_0', 'contract_1',
    'apt_idx',
    'area',
    'grid_id',
    'nearest_subway_distance',
    'nearest_subway_idx',
    # 'num_subway_within_1km',
    # 'category_interchange_within_1km',
    # 'num_subway_within_500m', 
    # 'category_interchange_within_500m',
    'nearest_elementary_school_distance',
    # 'nearest_elementary_school_within_1km',
    # 'has_elementary_school_within_1km',
    'nearest_middle_school_distance',
    # 'nearest_middle_school_within_1km',
    # 'has_middle_school_within_1km',
    'nearest_high_school_distance',
    # 'nearest_high_school_within_1km',
    # 'has_high_school_within_1km',
    'nearest_park_distance',
    # 'nearest_park_within_500.0m',
    # 'has_park_within_500.0m',
    'apt_deposit_rank', 'apt_area_deposit_rank',
    'recent_deposit',
    'interchange_2',
    'apt_floor_deposit_rank',
    'deposit_xgb',
    # 'apt_age_deposit_rank',
    # 'interest_rate', 
    # 'diff_interest_rate',
]
train_df = train_data[column_needed]
test_df = test_data[test_column_needed]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# # 학습에 사용할 특징 열
# feature_columns = [col for col in data.columns if col not in ['deposit', '_type', 'index']]
# 학습 및 테스트 데이터 준비
X_train = train_df.drop(columns=['deposit'])
y_train = train_df['deposit']
X_test = test_df.copy()
# 학습 데이터를 검증용으로 분할
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.2,
                                                                          random_state=42)
# XGBoost를 위한 DMatrix 생성
dtrain = xgb.DMatrix(X_train_split, label=y_train_split)
dval = xgb.DMatrix(X_val_split, label=y_val_split)
dtest = xgb.DMatrix(X_test)
# XGBoost 파라미터 설정
params = {
    'objective': 'reg:absoluteerror',
    'eval_metric': 'mae',
    'max_depth': 6,
    'eta': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}
# 모델 학습
evals = [(dtrain, 'train'), (dval, 'eval')]
model = xgb.train(params, dtrain, num_boost_round=500, early_stopping_rounds=50, evals=evals, verbose_eval=10)
# 테스트 세트에 대한 예측
y_pred = model.predict(dtest)
# Out:
# [0]	train-mae:16464.45676	eval-mae:16466.07340
# [10]	train-mae:11049.62328	eval-mae:11058.20231
# [20]	train-mae:7731.46794	eval-mae:7737.13333
# [30]	train-mae:5796.51293	eval-mae:5800.03398
# [40]	train-mae:4781.13547	eval-mae:4786.16698
# [50]	train-mae:4270.39265	eval-mae:4278.62314
# [60]	train-mae:4030.07894	eval-mae:4042.47469
# [70]	train-mae:3924.71605	eval-mae:3939.80683
# [80]	train-mae:3875.48258	eval-mae:3892.16999
# [90]	train-mae:3849.64203	eval-mae:3867.70751
# [100]	train-mae:3834.21065	eval-mae:3853.10997
# [110]	train-mae:3822.96153	eval-mae:3842.37512
# [120]	train-mae:3816.78772	eval-mae:3836.78335
# [130]	train-mae:3812.36132	eval-mae:3832.63182
# [140]	train-mae:3809.46010	eval-mae:3830.04614
# [150]	train-mae:3805.78654	eval-mae:3826.75599
# [160]	train-mae:3797.13756	eval-mae:3818.78944
# [170]	train-mae:3787.78850	eval-mae:3810.06715
# [180]	train-mae:3777.98387	eval-mae:3801.01272
# [190]	train-mae:3771.29879	eval-mae:3795.46611
# [200]	train-mae:3764.80359	eval-mae:3789.76068
# [210]	train-mae:3759.52380	eval-mae:3785.20480
# [220]	train-mae:3755.94873	eval-mae:3782.20890
# [230]	train-mae:3750.76968	eval-mae:3777.78196
# [240]	train-mae:3745.73691	eval-mae:3773.38303
# [250]	train-mae:3742.49030	eval-mae:3770.67100
# [260]	train-mae:3739.01237	eval-mae:3767.63189
# [270]	train-mae:3736.62263	eval-mae:3765.65558
# [280]	train-mae:3734.15293	eval-mae:3763.65454
# [290]	train-mae:3729.46686	eval-mae:3759.41935
# [300]	train-mae:3726.82115	eval-mae:3757.17195
# [310]	train-mae:3723.42687	eval-mae:3754.19887
# [320]	train-mae:3720.09668	eval-mae:3751.32226
# [330]	train-mae:3716.76168	eval-mae:3748.63014
# [340]	train-mae:3715.41661	eval-mae:3747.49208
# [350]	train-mae:3713.69780	eval-mae:3746.09441
# [360]	train-mae:3712.03337	eval-mae:3744.83408
# [370]	train-mae:3708.96323	eval-mae:3742.36512
# [380]	train-mae:3705.63915	eval-mae:3739.45810
# [390]	train-mae:3701.88522	eval-mae:3736.20015
# [400]	train-mae:3699.87864	eval-mae:3734.54300
# [410]	train-mae:3696.62495	eval-mae:3731.48302
# [420]	train-mae:3693.68807	eval-mae:3728.92212
# [430]	train-mae:3690.51842	eval-mae:3726.33298
# [440]	train-mae:3689.06418	eval-mae:3725.19651
# [450]	train-mae:3687.74544	eval-mae:3724.08692
# [460]	train-mae:3686.22390	eval-mae:3722.79743
# [470]	train-mae:3685.08668	eval-mae:3721.87433
# [480]	train-mae:3683.44064	eval-mae:3720.61536
# [490]	train-mae:3682.23114	eval-mae:3719.58706
# [499]	train-mae:3680.18781	eval-mae:3717.65733

# %%
#Feature Importance
# 피처 중요도 추출
feature_importance = model.get_fscore()
# 피처 중요도를 DataFrame으로 변환
importance_df = pd.DataFrame(feature_importance.items(), columns=['Feature', 'Importance'])
# 중요도 순으로 정렬
importance_df = importance_df.sort_values(by='Importance', ascending=False)
# 시각화
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.show()

# %%
y_pred.mean()
# Out:
# np.float32(38970.883)

# %%
sample_submission['deposit'] = y_pred
sample_submission
# Out:
#          index       deposit
# 0            0  22538.445312
# 1            1   7690.486328
# 2            2   6733.950195
# 3            3   6708.965820
# 4            4   6764.403320
# ...        ...           ...
# 150167  150167  37089.187500
# 150168  150168  45151.945312
# 150169  150169  43809.570312
# 150170  150170  37277.171875
# 150171  150171  36984.910156
#
# [150172 rows x 2 columns]

# %%
sample_submission.to_csv('v4_add(apt_floor_rank_deposit_xgboost).csv', index=False, encoding='utf-8-sig')
