# %% [markdown]
# # 라이브러리 불러오기

# %%
import os
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # 랜덤 시드 설정

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # 데이터 불러오기

# %%
BASE_PATH = r'C:\Users\com\Documents\GitHub\level2-competitiveds-recsys-06\data\etc'

train_data = pd.read_csv(os.path.join(BASE_PATH, 'train.csv'))
test_data = pd.read_csv(os.path.join(BASE_PATH, 'test.csv'))
sample_submission = pd.read_csv(os.path.join(BASE_PATH, 'sample_submission.csv'))

# %% [markdown]
# # 데이터 EDA 수행하기

# %%
print("train, test_data, sample_submission shape : ", train_data.shape, test_data.shape, sample_submission.shape)
print("train data 상단 5개 정보 확인 : ", train_data.head())
print("test data 상단 5개 정보 확인 : ", test_data.head())
print("sample_submission 상단 5개 정보 확인 : ", sample_submission.head())
print('train data 변수 요약 정보 확인 : ', train_data.describe())
print("test data 변수 요약 정보 확인 : ", test_data.describe())
# Out:
# train, test_data, sample_submission shape :  (1801228, 11) (150172, 10) (150172, 2)
# train data 상단 5개 정보 확인 :     index  area_m2  contract_year_month  contract_day  contract_type  floor  \
# 0      0  84.9981               201906            25              2      9
# 1      1  84.9981               202003            26              2     20
# 2      2  84.9981               202003            28              2      8
# 3      3  59.3400               201907            15              2      1
# 4      4  59.8100               201904            12              2      6
#
#    built_year   latitude   longitude  age  deposit
# 0        2019  37.054314  127.045216    0  17000.0
# 1        2019  37.054314  127.045216    1  23000.0
# 2        2019  37.054314  127.045216    1  23000.0
# 3        1986  36.964647  127.055847   33   5000.0
# 4        1995  36.972390  127.084514   24   1800.0
# test data 상단 5개 정보 확인 :     index  area_m2  contract_year_month  contract_day  contract_type  floor  \
# 0      0   84.961               202404            12              1     14
# 1      1   59.900               202404            13              0      4
# 2      2   39.270               202404            29              0      5
# 3      3   39.270               202405             3              0      1
# 4      4   46.980               202406             2              0      4
#
#    built_year   latitude   longitude  age
# 0        2016  36.965423  127.048779    8
# 1        1997  36.963105  127.040678   27
# 2        1990  36.957089  127.047449   34
# 3        1990  36.957089  127.047449   34
# 4        1990  36.957089  127.047449   34
# sample_submission 상단 5개 정보 확인 :     index  deposit
# 0      0        0
# 1      1        0
# 2      2        0
# 3      3        0
# 4      4        0
# train data 변수 요약 정보 확인 :                index       area_m2  contract_year_month  contract_day  \
# count  1.801228e+06  1.801228e+06         1.801228e+06  1.801228e+06
# mean   9.006135e+05  7.518833e+01         2.021331e+05  1.589943e+01
# std    5.199699e+05  2.552632e+01         1.352815e+02  8.625998e+00
# min    0.000000e+00  1.032150e+01         2.019040e+05  1.000000e+00
# 25%    4.503068e+05  5.975000e+01         2.020080e+05  9.000000e+00
# 50%    9.006135e+05  7.715000e+01         2.021110e+05  1.600000e+01
# 75%    1.350920e+06  8.496000e+01         2.022120e+05  2.300000e+01
# max    1.801227e+06  3.173600e+02         2.023120e+05  3.100000e+01
#
#        contract_type         floor    built_year      latitude     longitude  \
# count   1.801228e+06  1.801228e+06  1.801228e+06  1.801228e+06  1.801228e+06
# mean    1.203805e+00  1.005197e+01  2.004199e+03  3.747721e+01  1.269662e+02
# std     8.852792e-01  6.973359e+00  1.115132e+01  1.625113e-01  1.701221e-01
# min     0.000000e+00 -4.000000e+00  1.961000e+03  3.691791e+01  1.264787e+02
# 25%     0.000000e+00  5.000000e+00  1.995000e+03  3.737976e+01  1.268422e+02
# 50%     2.000000e+00  9.000000e+00  2.004000e+03  3.750227e+01  1.269976e+02
# 75%     2.000000e+00  1.400000e+01  2.015000e+03  3.758205e+01  1.270888e+02
# max     2.000000e+00  6.800000e+01  2.024000e+03  3.818194e+01  1.276609e+02
#
#                 age       deposit
# count  1.801228e+06  1.801228e+06
# mean   1.706597e+01  3.816223e+04
# std    1.112796e+01  2.610377e+04
# min   -3.000000e+00  3.000000e+02
# 25%    7.000000e+00  2.100000e+04
# 50%    1.700000e+01  3.200000e+04
# 75%    2.600000e+01  4.780000e+04
# max    6.200000e+01  1.100000e+06
# test data 변수 요약 정보 확인 :                index        area_m2  contract_year_month   contract_day  \
# count  150172.00000  150172.000000        150172.000000  150172.000000
# mean    75085.50000      74.509956        202403.137576      14.816650
# std     43351.06665      23.971424             1.645994       8.537693
# min         0.00000      10.780000        202401.000000       1.000000
# 25%     37542.75000      59.760000        202402.000000       7.000000
# 50%     75085.50000      75.793700        202403.000000      15.000000
# 75%    112628.25000      84.958200        202405.000000      22.000000
# max    150171.00000     273.860000        202406.000000      31.000000
#
#        contract_type          floor     built_year       latitude  \
# count  150172.000000  150172.000000  150172.000000  150172.000000
# mean        0.426071      10.060557    2004.908292      37.474571
# std         0.597423       6.982813      11.460352       0.166952
# min         0.000000      -3.000000    1966.000000      36.957089
# 25%         0.000000       5.000000    1995.000000      37.372616
# 50%         0.000000       9.000000    2004.000000      37.500382
# 75%         1.000000      14.000000    2016.000000      37.588872
# max         2.000000      60.000000    2024.000000      38.106033
#
#            longitude            age
# count  150172.000000  150172.000000
# mean      126.967625      19.091708
# std         0.172066      11.460352
# min       126.478708       0.000000
# 25%       126.841057       8.000000
# 50%       126.998922      20.000000
# 75%       127.091862      29.000000
# max       127.660896      58.000000

# %%
print(train_data.columns)
train_data.head()
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit'],
#       dtype='object')
#    index  area_m2  contract_year_month  contract_day  contract_type  floor  \
# 0      0  84.9981               201906            25              2      9
# 1      1  84.9981               202003            26              2     20
# 2      2  84.9981               202003            28              2      8
# 3      3  59.3400               201907            15              2      1
# 4      4  59.8100               201904            12              2      6
#
#    built_year   latitude   longitude  age  deposit
# 0        2019  37.054314  127.045216    0  17000.0
# 1        2019  37.054314  127.045216    1  23000.0
# 2        2019  37.054314  127.045216    1  23000.0
# 3        1986  36.964647  127.055847   33   5000.0
# 4        1995  36.972390  127.084514   24   1800.0

# %%
# train_data.shape #(1594362, 8)
train_data.groupby(by=["latitude", "longitude", "built_year"]).max()
# Out:
#                                   index   area_m2  contract_year_month  \
# latitude  longitude  built_year
# 36.917910 126.908029 1996        775455   84.5900               202304
# 36.957089 127.047449 1990        774308   46.9800               202311
# 36.959894 127.045371 2020        162840   83.2576               202103
# 36.960034 127.059939 2005        774337   84.5344               202309
# 36.960936 127.054219 2010        774345  179.6433               202311
# ...                                 ...       ...                  ...
# 38.096380 127.076702 2002        790509   60.7000               202305
# 38.101890 127.079581 1996        790527   84.9500               202312
# 38.104768 127.079949 2023        790615   84.9986               202312
# 38.106033 127.077652 2014        790516   84.8960               202311
# 38.181937 127.105145 1998         14694   83.2700               201910
#
#                                  contract_day  contract_type  floor  age  \
# latitude  longitude  built_year
# 36.917910 126.908029 1996                  28              2     14   27
# 36.957089 127.047449 1990                  31              2      5   33
# 36.959894 127.045371 2020                  22              2     12    1
# 36.960034 127.059939 2005                  31              2     13   18
# 36.960936 127.054219 2010                  20              2      8   13
# ...                                       ...            ...    ...  ...
# 38.096380 127.076702 2002                  30              2      6   21
# 38.101890 127.079581 1996                  31              2     13   27
# 38.104768 127.079949 2023                  31              2     23    0
# 38.106033 127.077652 2014                  29              2     14    9
# 38.181937 127.105145 1998                  16              2      1   21
#
#                                  deposit
# latitude  longitude  built_year
# 36.917910 126.908029 1996        10000.0
# 36.957089 127.047449 1990         8500.0
# 36.959894 127.045371 2020        23000.0
# 36.960034 127.059939 2005        19000.0
# 36.960936 127.054219 2010        37000.0
# ...                                  ...
# 38.096380 127.076702 2002         6500.0
# 38.101890 127.079581 1996         9500.0
# 38.104768 127.079949 2023        23000.0
# 38.106033 127.077652 2014        15000.0
# 38.181937 127.105145 1998         2500.0
#
# [18915 rows x 8 columns]

# %%
# train_data.shape #(1594362, 8)
train_data.groupby(by=["contract_type"]).count()
# Out:
#                 index  area_m2  contract_year_month  contract_day   floor  \
# contract_type
# 0              559687   559687               559687        559687  559687
# 1              314755   314755               314755        314755  314755
# 2              926786   926786               926786        926786  926786
#
#                built_year  latitude  longitude     age  deposit
# contract_type
# 0                  559687    559687     559687  559687   559687
# 1                  314755    314755     314755  314755   314755
# 2                  926786    926786     926786  926786   926786

# %% [markdown]
# ```python
# tarin_data.shape # == (1594362, 8)
# train_data.contract_year_month # min = 201904 / max = 202306
# area_m2 # min = 10.3215/ max 317.36
# deposit # min = 300 / 1,100,000
# ```
# 24년 지어진 건물의 최소 계약일자는 21년 9월 이며 최대 계약 일은 23년 12월이다.```python
# tarin_data.shape # == (1594362, 8)
# train_data.contract_year_month # min = 201904 / max = 202306
# area_m2 # min = 10.3215/ max 317.36
# deposit # min = 300 / 1,100,000
# ```
# 24년 지어진 건물의 최소 계약일자는 21년 9월 이며 최대 계약 일은 23년 12월이다.

# %% [markdown]
# # 대회에 필요한 데이터만 활용하기

# %%
import sys
import os

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(""))))
from src.pre_process.feature_add import FeatureAddition
from src.pre_process.feature_duplicate import FeatureDuplication

# %%
train_data["_type"] = "train"
test_data["_type"] = "test"

concat_df = pd.concat([train_data,test_data],axis=0)
df= FeatureAddition(concat_df).get_data()
df
# Out:
#          index   area_m2  contract_year_month  contract_day  contract_type  \
# 0            0   84.9981               201906            25              2
# 1            1   84.9981               202003            26              2
# 2            2   84.9981               202003            28              2
# 3            3   59.3400               201907            15              2
# 4            4   59.8100               201904            12              2
# ...        ...       ...                  ...           ...            ...
# 150167  150167  115.5101               202402            27              0
# 150168  150168  142.8738               202403             2              0
# 150169  150169  142.8738               202403            16              1
# 150170  150170  114.9285               202403            22              1
# 150171  150171  115.5101               202403            22              1
#
#         floor  built_year   latitude   longitude  age  deposit  _type  \
# 0           9        2019  37.054314  127.045216    0  17000.0  train
# 1          20        2019  37.054314  127.045216    1  23000.0  train
# 2           8        2019  37.054314  127.045216    1  23000.0  train
# 3           1        1986  36.964647  127.055847   33   5000.0  train
# 4           6        1995  36.972390  127.084514   24   1800.0  train
# ...       ...         ...        ...         ...  ...      ...    ...
# 150167     17        2010  37.528394  126.659398   14      NaN   test
# 150168      4        2010  37.528394  126.659398   14      NaN   test
# 150169     13        2010  37.528394  126.659398   14      NaN   test
# 150170      2        2010  37.528394  126.659398   14      NaN   test
# 150171      7        2010  37.528394  126.659398   14      NaN   test
#
#         apt_idx  area  area_price  area_m2_price
# 0             0  25.8  658.914729     200.004471
# 1             0  25.8  891.472868     270.594284
# 2             0  25.8  891.472868     270.594284
# 3             1  18.0  277.777778      84.260195
# 4             2  18.1   99.447514      30.095302
# ...         ...   ...         ...            ...
# 150167    17869  35.0         NaN            NaN
# 150168    17869  43.3         NaN            NaN
# 150169    17869  43.3         NaN            NaN
# 150170    17869  34.8         NaN            NaN
# 150171    17869  35.0         NaN            NaN
#
# [1951400 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# index                       0
# area_m2                     0
# contract_year_month         0
# contract_day                0
# contract_type               0
# floor                       0
# built_year                  0
# latitude                    0
# longitude                   0
# age                         0
# deposit                150172
# _type                       0
# apt_idx                     0
# area                        0
# area_price             150172
# area_m2_price          150172
# dtype: int64

# %%
from src.pre_procecss.interest.diff_interestrate import DiffInterestRateAdder
interst = pd.read_csv(os.path.join(BASE_PATH, 'interestRate.csv'))
interest_data = DiffInterestRateAdder(df, interst).get_data()

# %%
interest_data
# Out:
#           index   area_m2 contract_year_month  contract_day  contract_type  \
# 0             0   84.9981          2019-06-01            25              2
# 1             1   84.9981          2020-03-01            26              2
# 2             2   84.9981          2020-03-01            28              2
# 3             3   59.3400          2019-07-01            15              2
# 4             4   59.8100          2019-04-01            12              2
# ...         ...       ...                 ...           ...            ...
# 1951395  150167  115.5101          2024-02-01            27              0
# 1951396  150168  142.8738          2024-03-01             2              0
# 1951397  150169  142.8738          2024-03-01            16              1
# 1951398  150170  114.9285          2024-03-01            22              1
# 1951399  150171  115.5101          2024-03-01            22              1
#
#          floor  built_year   latitude   longitude  age  deposit  _type  \
# 0            9        2019  37.054314  127.045216    0  17000.0  train
# 1           20        2019  37.054314  127.045216    1  23000.0  train
# 2            8        2019  37.054314  127.045216    1  23000.0  train
# 3            1        1986  36.964647  127.055847   33   5000.0  train
# 4            6        1995  36.972390  127.084514   24   1800.0  train
# ...        ...         ...        ...         ...  ...      ...    ...
# 1951395     17        2010  37.528394  126.659398   14      NaN   test
# 1951396      4        2010  37.528394  126.659398   14      NaN   test
# 1951397     13        2010  37.528394  126.659398   14      NaN   test
# 1951398      2        2010  37.528394  126.659398   14      NaN   test
# 1951399      7        2010  37.528394  126.659398   14      NaN   test
#
#          apt_idx  area  area_price  area_m2_price year_month  interest_rate  \
# 0              0  25.8  658.914729     200.004471 2019-06-01           1.78
# 1              0  25.8  891.472868     270.594284 2020-03-01           1.26
# 2              0  25.8  891.472868     270.594284 2020-03-01           1.26
# 3              1  18.0  277.777778      84.260195 2019-07-01           1.68
# 4              2  18.1   99.447514      30.095302 2019-04-01           1.85
# ...          ...   ...         ...            ...        ...            ...
# 1951395    17869  35.0         NaN            NaN 2024-02-01           3.62
# 1951396    17869  43.3         NaN            NaN 2024-03-01           3.59
# 1951397    17869  43.3         NaN            NaN 2024-03-01           3.59
# 1951398    17869  34.8         NaN            NaN 2024-03-01           3.59
# 1951399    17869  35.0         NaN            NaN 2024-03-01           3.59
#
#          diff_interest_rate
# 0                     -0.07
# 1                     -0.17
# 2                     -0.17
# 3                     -0.10
# 4                     -0.09
# ...                     ...
# 1951395               -0.04
# 1951396               -0.03
# 1951397               -0.03
# 1951398               -0.03
# 1951399               -0.03
#
# [1951400 rows x 19 columns]

# %%
interest_data.isnull().sum()
# Out:
# index                       0
# area_m2                     0
# contract_year_month         0
# contract_day                0
# contract_type               0
# floor                       0
# built_year                  0
# latitude                    0
# longitude                   0
# age                         0
# deposit                150172
# _type                       0
# apt_idx                     0
# area                        0
# area_price             150172
# area_m2_price          150172
# year_month              11882
# interest_rate           11882
# diff_interest_rate      11882
# dtype: int64

# %%
from src.pre_process.deposit.grid_deposit import GridFeature

# %%
preprocessor = GridFeature(df)
pre_data = preprocessor.get_data()

# %%
pre_data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id'],
#       dtype='object')

# %%
pre_data.isnull().sum()
# Out:
# index                       0
# area_m2                     0
# contract_year_month         0
# contract_day                0
# contract_type               0
# floor                       0
# built_year                  0
# latitude                    0
# longitude                   0
# age                         0
# deposit                150172
# _type                       0
# apt_idx                     0
# area                        0
# area_price             150172
# area_m2_price          150172
# grid_id                     0
# dtype: int64

# %%
from src.pre_process.subway.subway_distance_feature_add import SubwayDistanceFeatureAddition

# %%
subway_info = pd.read_csv(os.path.join(BASE_PATH, 'subwayinfo.csv'))

# %%
subway_add = SubwayDistanceFeatureAddition(pre_data,subway_info)
sub_data = subway_add.get_data()

# %%
sub_data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m'],
#       dtype='object')

# %%
sub_data.isnull().sum()
# Out:
# index                                    0
# area_m2                                  0
# contract_year_month                      0
# contract_day                             0
# contract_type                            0
# floor                                    0
# built_year                               0
# latitude                                 0
# longitude                                0
# age                                      0
# deposit                             150172
# _type                                    0
# apt_idx                                  0
# area                                     0
# area_price                          150172
# area_m2_price                       150172
# grid_id                                  0
# nearest_subway_distance                  0
# nearest_subway_idx                       0
# num_subway_within_1km                    0
# category_interchange_within_1km          0
# num_subway_within_500m                   0
# category_interchange_within_500m         0
# dtype: int64

# %%
from src.pre_process.school.school_info_feature_add import SchoolInfoFeatureAdd

# %%
school_info = pd.read_csv(os.path.join(BASE_PATH, 'schoolinfo.csv'))

# %%
school_add = SchoolInfoFeatureAdd(sub_data,school_info)
school_data = school_add.get_data()

# %%
school_data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km'],
#       dtype='object')

# %%
school_data.isnull().sum()
# Out:
# index                                        0
# area_m2                                      0
# contract_year_month                          0
# contract_day                                 0
# contract_type                                0
# floor                                        0
# built_year                                   0
# latitude                                     0
# longitude                                    0
# age                                          0
# deposit                                 150172
# _type                                        0
# apt_idx                                      0
# area                                         0
# area_price                              150172
# area_m2_price                           150172
# grid_id                                      0
# nearest_subway_distance                      0
# nearest_subway_idx                           0
# num_subway_within_1km                        0
# category_interchange_within_1km              0
# num_subway_within_500m                       0
# category_interchange_within_500m             0
# nearest_elementary_school_distance           0
# nearest_elementary_school_within_1km         0
# has_elementary_school_within_1km             0
# nearest_middle_school_distance               0
# nearest_middle_school_within_1km             0
# has_middle_school_within_1km                 0
# nearest_high_school_distance                 0
# nearest_high_school_within_1km               0
# has_high_school_within_1km                   0
# dtype: int64

# %%
from src.pre_process.park.park_info_feature_add import ParkInfoFeatureAdd

# %%
park_info = pd.read_csv(os.path.join(BASE_PATH, 'parkinfo.csv'))

# %%
park_add = ParkInfoFeatureAdd(school_data,park_info)
park_data = park_add.get_data()

# %%
park_data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'nearest_park_distance',
#        'nearest_park_within_500.0m', 'has_park_within_500.0m'],
#       dtype='object')

# %%
from src.pre_procecss.interest.diff_interestrate import DiffInterestRateAdder

# %%
interst = pd.read_csv(os.path.join(BASE_PATH, 'interestRate.csv'))

# %%
interest_add = DiffInterestRateAdder(park_data, interst)
interest_data = interest_add.get_data()

# %%
interest_data
# Out:
#           index   area_m2 contract_year_month  contract_day  contract_type  \
# 0             0   84.9981          2019-06-01            25              2
# 1             1   84.9981          2020-03-01            26              2
# 2             2   84.9981          2020-03-01            28              2
# 3             3   59.3400          2019-07-01            15              2
# 4             4   59.8100          2019-04-01            12              2
# ...         ...       ...                 ...           ...            ...
# 1939513  150167  115.5101          2024-02-01            27              0
# 1939514  150168  142.8738          2024-03-01             2              0
# 1939515  150169  142.8738          2024-03-01            16              1
# 1939516  150170  114.9285          2024-03-01            22              1
# 1939517  150171  115.5101          2024-03-01            22              1
#
#          floor  built_year   latitude   longitude  age  ...  \
# 0            9        2019  37.054314  127.045216    0  ...
# 1           20        2019  37.054314  127.045216    1  ...
# 2            8        2019  37.054314  127.045216    1  ...
# 3            1        1986  36.964647  127.055847   33  ...
# 4            6        1995  36.972390  127.084514   24  ...
# ...        ...         ...        ...         ...  ...  ...
# 1939513     17        2010  37.528394  126.659398   14  ...
# 1939514      4        2010  37.528394  126.659398   14  ...
# 1939515     13        2010  37.528394  126.659398   14  ...
# 1939516      2        2010  37.528394  126.659398   14  ...
# 1939517      7        2010  37.528394  126.659398   14  ...
#
#          has_middle_school_within_1km nearest_high_school_distance  \
# 0                                True                   990.854810
# 1                                True                   990.854810
# 2                                True                   990.854810
# 3                                True                   644.366430
# 4                               False                  2264.821766
# ...                               ...                          ...
# 1939513                          True                   224.754177
# 1939514                          True                   224.754177
# 1939515                          True                   224.754177
# 1939516                          True                   224.754177
# 1939517                          True                   224.754177
#
#          nearest_high_school_within_1km  has_high_school_within_1km  \
# 0                                     1                        True
# 1                                     1                        True
# 2                                     1                        True
# 3                                     1                        True
# 4                                     0                       False
# ...                                 ...                         ...
# 1939513                               2                        True
# 1939514                               2                        True
# 1939515                               2                        True
# 1939516                               2                        True
# 1939517                               2                        True
#
#          nearest_park_distance  nearest_park_within_500.0m  \
# 0                   498.618918                           1
# 1                   498.618918                           1
# 2                   498.618918                           1
# 3                   169.839678                           3
# 4                   382.401815                           1
# ...                        ...                         ...
# 1939513             398.113485                           1
# 1939514             398.113485                           1
# 1939515             398.113485                           1
# 1939516             398.113485                           1
# 1939517             398.113485                           1
#
#          has_park_within_500.0m  year_month  interest_rate  diff_interest_rate
# 0                          True  2019-06-01           1.78               -0.07
# 1                          True  2020-03-01           1.26               -0.17
# 2                          True  2020-03-01           1.26               -0.17
# 3                          True  2019-07-01           1.68               -0.10
# 4                          True  2019-04-01           1.85               -0.09
# ...                         ...         ...            ...                 ...
# 1939513                    True  2024-02-01           3.62               -0.04
# 1939514                    True  2024-03-01           3.59               -0.03
# 1939515                    True  2024-03-01           3.59               -0.03
# 1939516                    True  2024-03-01           3.59               -0.03
# 1939517                    True  2024-03-01           3.59               -0.03
#
# [1939518 rows x 38 columns]

# %%
interest_data.isn
# Out:
#           index   area_m2 contract_year_month  contract_day  contract_type  \
# 0             0   84.9981          2019-06-01            25              2
# 1             1   84.9981          2020-03-01            26              2
# 2             2   84.9981          2020-03-01            28              2
# 3             3   59.3400          2019-07-01            15              2
# 4             4   59.8100          2019-04-01            12              2
# ...         ...       ...                 ...           ...            ...
# 1939513  150167  115.5101          2024-02-01            27              0
# 1939514  150168  142.8738          2024-03-01             2              0
# 1939515  150169  142.8738          2024-03-01            16              1
# 1939516  150170  114.9285          2024-03-01            22              1
# 1939517  150171  115.5101          2024-03-01            22              1
#
#          floor  built_year   latitude   longitude  age  ...  \
# 0            9        2019  37.054314  127.045216    0  ...
# 1           20        2019  37.054314  127.045216    1  ...
# 2            8        2019  37.054314  127.045216    1  ...
# 3            1        1986  36.964647  127.055847   33  ...
# 4            6        1995  36.972390  127.084514   24  ...
# ...        ...         ...        ...         ...  ...  ...
# 1939513     17        2010  37.528394  126.659398   14  ...
# 1939514      4        2010  37.528394  126.659398   14  ...
# 1939515     13        2010  37.528394  126.659398   14  ...
# 1939516      2        2010  37.528394  126.659398   14  ...
# 1939517      7        2010  37.528394  126.659398   14  ...
#
#          has_middle_school_within_1km nearest_high_school_distance  \
# 0                                True                   990.854810
# 1                                True                   990.854810
# 2                                True                   990.854810
# 3                                True                   644.366430
# 4                               False                  2264.821766
# ...                               ...                          ...
# 1939513                          True                   224.754177
# 1939514                          True                   224.754177
# 1939515                          True                   224.754177
# 1939516                          True                   224.754177
# 1939517                          True                   224.754177
#
#          nearest_high_school_within_1km  has_high_school_within_1km  \
# 0                                     1                        True
# 1                                     1                        True
# 2                                     1                        True
# 3                                     1                        True
# 4                                     0                       False
# ...                                 ...                         ...
# 1939513                               2                        True
# 1939514                               2                        True
# 1939515                               2                        True
# 1939516                               2                        True
# 1939517                               2                        True
#
#          nearest_park_distance  nearest_park_within_500.0m  \
# 0                   498.618918                           1
# 1                   498.618918                           1
# 2                   498.618918                           1
# 3                   169.839678                           3
# 4                   382.401815                           1
# ...                        ...                         ...
# 1939513             398.113485                           1
# 1939514             398.113485                           1
# 1939515             398.113485                           1
# 1939516             398.113485                           1
# 1939517             398.113485                           1
#
#          has_park_within_500.0m  year_month  interest_rate  diff_interest_rate
# 0                          True  2019-06-01           1.78               -0.07
# 1                          True  2020-03-01           1.26               -0.17
# 2                          True  2020-03-01           1.26               -0.17
# 3                          True  2019-07-01           1.68               -0.10
# 4                          True  2019-04-01           1.85               -0.09
# ...                         ...         ...            ...                 ...
# 1939513                    True  2024-02-01           3.62               -0.04
# 1939514                    True  2024-03-01           3.59               -0.03
# 1939515                    True  2024-03-01           3.59               -0.03
# 1939516                    True  2024-03-01           3.59               -0.03
# 1939517                    True  2024-03-01           3.59               -0.03
#
# [1939518 rows x 38 columns]

# %%
park_data['interest_rate'] = interest_data['interest_rate']
park_data['diff_interest_rate'] = interest_data['diff_interest_rate']
park_data['contract_year_month'] = school_data['contract_year_month']

# %%
park_data.isnull().sum()
# Out:
# index                                        0
# area_m2                                      0
# contract_year_month                          0
# contract_day                                 0
# contract_type                                0
# floor                                        0
# built_year                                   0
# latitude                                     0
# longitude                                    0
# age                                          0
# deposit                                 150172
# _type                                        0
# apt_idx                                      0
# area                                         0
# area_price                              150172
# area_m2_price                           150172
# grid_id                                      0
# nearest_subway_distance                      0
# nearest_subway_idx                           0
# num_subway_within_1km                        0
# category_interchange_within_1km              0
# num_subway_within_500m                       0
# category_interchange_within_500m             0
# nearest_elementary_school_distance           0
# nearest_elementary_school_within_1km         0
# has_elementary_school_within_1km             0
# nearest_middle_school_distance               0
# nearest_middle_school_within_1km             0
# has_middle_school_within_1km                 0
# nearest_high_school_distance                 0
# nearest_high_school_within_1km               0
# has_high_school_within_1km                   0
# nearest_park_distance                        0
# nearest_park_within_500.0m                   0
# has_park_within_500.0m                       0
# interest_rate                            11882
# diff_interest_rate                       11882
# dtype: int64

# %%
park_data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'nearest_park_distance',
#        'nearest_park_within_500.0m', 'has_park_within_500.0m', 'interest_rate',
#        'diff_interest_rate'],
#       dtype='object')

# %%
park_data.to_csv('v3_baek.csv',index=False)

# %%
park_data[['apt_idx','deposit']].corr()
# Out:
#           apt_idx   deposit
# apt_idx  1.000000  0.220488
# deposit  0.220488  1.000000

# %% [markdown]
# # Recent Deposit 확인

# %%
recent_deposit = pd.read_csv(os.path.join(BASE_PATH, 'all_apt_idx_recent_deposit.csv'))
recent_deposit
# Out:
#            index  area_m2  contract_year_month  contract_day  contract_type  \
# 0              0  72.3200               201904             1              2
# 1              1  22.2700               201904             1              2
# 2              2  59.9400               201904             1              2
# 3              3  59.7600               201904             1              2
# 4              4  58.7640               201904             1              2
# ...          ...      ...                  ...           ...            ...
# 1951395  1951395  84.8086               202406            20              0
# 1951396  1951396  84.9947               202406            20              0
# 1951397  1951397  61.0093               202406            20              0
# 1951398  1951398  58.0500               202406            20              0
# 1951399  1951399  84.9100               202406            20              0
#
#          floor  built_year   latitude   longitude  age  deposit contract_ymd  \
# 0           16        2016  36.977063  126.928605    3  17000.0   2019-04-01
# 1           11        2013  36.989441  126.842601    6   4000.0   2019-04-01
# 2            9        1996  37.126312  127.070305   23   9000.0   2019-04-01
# 3            1        1992  36.961599  126.918827   27   3000.0   2019-04-01
# 4           12        2005  37.589086  127.206811   14  18000.0   2019-04-01
# ...        ...         ...        ...         ...  ...      ...          ...
# 1951395      1        2022  37.604125  126.711206    2   -999.0   2024-06-20
# 1951396     20        2022  37.599620  126.706729    2   -999.0   2024-06-20
# 1951397      2        2024  37.885999  127.196120    0   -999.0   2024-06-20
# 1951398      3        1996  37.489146  126.886988   28   -999.0   2024-06-20
# 1951399     25        2024  37.494573  126.557237    0   -999.0   2024-06-20
#
#          recent_deposit  apt_idx  area   area_price  area_m2_price
# 0                -999.0       15  21.9   776.255708     235.066372
# 1                -999.0       36   6.7   597.014925     179.613830
# 2                -999.0       53  18.2   494.505495     150.150150
# 3                -999.0       64  18.1   165.745856      50.200803
# 4                -999.0       67  17.8  1011.235955     306.309986
# ...                 ...      ...   ...          ...            ...
# 1951395         30000.0    18460  25.7   -38.871595     -11.779466
# 1951396         35000.0    18462  25.8   -38.720930     -11.753674
# 1951397          -999.0    18536  18.5   -54.000000     -16.374553
# 1951398          -999.0    18590  17.6   -56.761364     -17.209302
# 1951399          -999.0    18615  25.7   -38.871595     -11.765399
#
# [1951400 rows x 17 columns]

# %%
recent_deposit[['deposit','recent_deposit']].corr()
# Out:
#                  deposit  recent_deposit
# deposit         1.000000        0.756467
# recent_deposit  0.756467        1.000000

# %%
recent_deposit[recent_deposit['apt_idx']==15571]
# Out:
#            index  area_m2  contract_year_month  contract_day  contract_type  \
# 899831    899831   273.96               202111            12              0
# 1280137  1280137   273.96               202210            13              0
# 1509058  1509058   273.96               202304            20              1
# 1602284  1602284   273.96               202307             7              2
#
#          floor  built_year   latitude   longitude  age    deposit  \
# 899831      14        2020  37.525956  127.054237    1   930000.0
# 1280137     18        2020  37.525956  127.054237    2  1100000.0
# 1509058      2        2020  37.525956  127.054237    3   570000.0
# 1602284     14        2020  37.525956  127.054237    3  1000000.0
#
#         contract_ymd  recent_deposit  apt_idx  area    area_price  \
# 899831    2021-11-12          -999.0    15571  83.0  11204.819277
# 1280137   2022-10-13        930000.0    15571  83.0  13253.012048
# 1509058   2023-04-20       1100000.0    15571  83.0   6867.469880
# 1602284   2023-07-07        930000.0    15571  83.0  12048.192771
#
#          area_m2_price
# 899831     3394.656154
# 1280137    4015.184698
# 1509058    2080.595707
# 1602284    3650.167908

# %%
v2 = pd.read_csv(os.path.join(BASE_PATH,'V2_features.csv'))

# %%
v2.loc[v2['apt_idx'] == 15571, 
       ['area_m2', 'contract_type', 'floor', 'built_year', 
        'latitude', 'longitude', 'age', 'deposit', 'recent_deposit']]
# Out:
#          area_m2  contract_type  floor  built_year   latitude   longitude  \
# 1260709   273.96              0     14        2020  37.525956  127.054237
# 1406833   273.96              0     18        2020  37.525956  127.054237
# 1539384   273.96              1      2        2020  37.525956  127.054237
# 1542638   273.96              2     14        2020  37.525956  127.054237
#
#          age    deposit  recent_deposit
# 1260709    1   930000.0        100000.0
# 1406833    2  1100000.0         50000.0
# 1539384    3   570000.0         87000.0
# 1542638    3  1000000.0         57700.0

# %%
recent_deposit[recent_deposit['index']==1406833]
# Out:
#            index  area_m2  contract_year_month  contract_day  contract_type  \
# 1406833  1406833   134.88               202302             8              0
#
#          floor  built_year   latitude   longitude  age  deposit contract_ymd  \
# 1406833     13        1994  37.679009  126.762119   29  30000.0   2023-02-08
#
#          recent_deposit  apt_idx  area  area_price  area_m2_price
# 1406833         50000.0     4182  40.9  733.496333     222.419929

# %% [markdown]
# # v4 feature 파일

# %%
data = pd.read_csv(os.path.join(BASE_PATH,'v4_baek+recent+rank.csv'))

# %%
data.drop(columns=['original_index'],inplace=True)

# %%
data.columns
# Out:
# Index(['index', 'area_m2', 'contract_year_month', 'contract_day',
#        'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
#        'deposit', '_type', 'apt_idx', 'area', 'area_price', 'area_m2_price',
#        'grid_id', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'nearest_park_distance',
#        'nearest_park_within_500.0m', 'has_park_within_500.0m',
#        'apt_deposit_rank', 'apt_area_deposit_rank', 'recent_deposit',
#        'interest_rate', 'diff_interest_rate'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# index                                        0
# area_m2                                      0
# contract_year_month                          0
# contract_day                                 0
# contract_type                                0
# floor                                        0
# built_year                                   0
# latitude                                     0
# longitude                                    0
# age                                          0
# deposit                                 150172
# _type                                        0
# apt_idx                                      0
# area                                         0
# area_price                              150172
# area_m2_price                           150172
# grid_id                                      0
# nearest_subway_distance                      0
# nearest_subway_idx                           0
# num_subway_within_1km                        0
# category_interchange_within_1km              0
# num_subway_within_500m                       0
# category_interchange_within_500m             0
# nearest_elementary_school_distance           0
# nearest_elementary_school_within_1km         0
# has_elementary_school_within_1km             0
# nearest_middle_school_distance               0
# nearest_middle_school_within_1km             0
# has_middle_school_within_1km                 0
# nearest_high_school_distance                 0
# nearest_high_school_within_1km               0
# has_high_school_within_1km                   0
# nearest_park_distance                        0
# nearest_park_within_500.0m                   0
# has_park_within_500.0m                       0
# apt_deposit_rank                             0
# apt_area_deposit_rank                        0
# recent_deposit                           67857
# interest_rate                                0
# diff_interest_rate                           0
# dtype: int64

# %%
data
# Out:
#           index   area_m2  contract_year_month  contract_day  contract_type  \
# 0             0   84.9981               201906            25              2
# 1             1   84.9981               202003            26              2
# 2             2   84.9981               202003            28              2
# 3             3   59.3400               201907            15              2
# 4             4   59.8100               201904            12              2
# ...         ...       ...                  ...           ...            ...
# 1951395  150167  115.5101               202402            27              0
# 1951396  150168  142.8738               202403             2              0
# 1951397  150169  142.8738               202403            16              1
# 1951398  150170  114.9285               202403            22              1
# 1951399  150171  115.5101               202403            22              1
#
#          floor  built_year   latitude   longitude  age  ...  \
# 0            9        2019  37.054314  127.045216    0  ...
# 1           20        2019  37.054314  127.045216    1  ...
# 2            8        2019  37.054314  127.045216    1  ...
# 3            1        1986  36.964647  127.055847   33  ...
# 4            6        1995  36.972390  127.084514   24  ...
# ...        ...         ...        ...         ...  ...  ...
# 1951395     17        2010  37.528394  126.659398   14  ...
# 1951396      4        2010  37.528394  126.659398   14  ...
# 1951397     13        2010  37.528394  126.659398   14  ...
# 1951398      2        2010  37.528394  126.659398   14  ...
# 1951399      7        2010  37.528394  126.659398   14  ...
#
#          nearest_high_school_within_1km has_high_school_within_1km  \
# 0                                     1                          1
# 1                                     1                          1
# 2                                     1                          1
# 3                                     1                          1
# 4                                     0                          0
# ...                                 ...                        ...
# 1951395                               2                          1
# 1951396                               2                          1
# 1951397                               2                          1
# 1951398                               2                          1
# 1951399                               2                          1
#
#          nearest_park_distance  nearest_park_within_500.0m  \
# 0                   498.618918                           1
# 1                   498.618918                           1
# 2                   498.618918                           1
# 3                   169.839678                           3
# 4                   382.401815                           1
# ...                        ...                         ...
# 1951395             398.113485                           1
# 1951396             398.113485                           1
# 1951397             398.113485                           1
# 1951398             398.113485                           1
# 1951399             398.113485                           1
#
#          has_park_within_500.0m  apt_deposit_rank  apt_area_deposit_rank  \
# 0                             1              7683                  29300
# 1                             1              7683                  29300
# 2                             1              7683                  29300
# 3                             1             18366                  58901
# 4                             1             18369                  58863
# ...                         ...               ...                    ...
# 1951395                       1              6088                  25360
# 1951396                       1              6088                  17911
# 1951397                       1              6088                  17911
# 1951398                       1              6088                  24128
# 1951399                       1              6088                  25360
#
#          recent_deposit  interest_rate  diff_interest_rate
# 0                   NaN           1.78               -0.07
# 1               17000.0           1.26               -0.17
# 2               23000.0           1.26               -0.17
# 3                   NaN           1.68               -0.10
# 4                   NaN           1.85               -0.09
# ...                 ...            ...                 ...
# 1951395         37000.0           3.62               -0.04
# 1951396         43000.0           3.59               -0.03
# 1951397         43000.0           3.59               -0.03
# 1951398         32500.0           3.59               -0.03
# 1951399         37000.0           3.59               -0.03
#
# [1951400 rows x 40 columns]

# %%
data['apt_idx'].value_counts()
# Out:
# apt_idx
# 167      5463
# 13661    4043
# 13598    3447
# 13330    3034
# 13584    2902
#          ...
# 13648       1
# 5831        1
# 13651       1
# 7084        1
# 18675       1
# Name: count, Length: 18676, dtype: int64

# %%
columns_needed = [
       'area_m2', 'contract_year_month', 
       'contract_day',
       'floor', 'built_year', 'latitude', 'longitude', 'age', 'deposit',
       # 'apt_idx',
       'grid_id', 
       # 'log_grid_id',
       # 'nearest_subway_distance', 'nearest_subway_idx',
       # 'num_subway_within_1km', 'category_interchange_within_1km',
       # 'num_subway_within_500m', 'category_interchange_within_500m',
       # 'nearest_elementary_school_distance','nearest_elementary_school_within_1km',
       # 'has_elementary_school_within_1km', 'nearest_middle_school_distance',
       # 'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
       # 'nearest_high_school_distance', 'nearest_high_school_within_1km',
       # 'has_high_school_within_1km', 
       # 'nearest_park_distance','nearest_park_within_500.0m', 'has_park_within_500.0m', 
       'interest_rate', 
       'diff_interest_rate',
       'apt_deposit_rank', 'apt_area_deposit_rank',
       'recent_deposit'
       ]

# %%
train = data[data['_type']== 'train']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (혹은 사용하고자 하는 데이터 로드)
# df = pd.read_csv('your_dataset.csv')

# 상관관계 계산
corr = train[columns_needed].corr()

# 히트맵 생성
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # V5

# %%
data = pd.read_csv(os.path.join(BASE_PATH,'V5-2024-10-16-YDS-APT-RANK-RecentD.csv'))

# %%
data.columns
# Out:
# Index(['index', '_type', 'area_m2', 'contract_type', 'floor', 'built_year',
#        'latitude', 'longitude', 'age', 'deposit', 'apt_idx', 'area',
#        'area_m2_price', 'nearest_subway_distance', 'nearest_subway_idx',
#        'num_subway_within_1km', 'category_interchange_within_1km',
#        'num_subway_within_500m', 'category_interchange_within_500m',
#        'nearest_park_distance', 'nearest_park_within_500.0m',
#        'has_park_within_500.0m', 'nearest_elementary_school_distance',
#        'nearest_elementary_school_within_1km',
#        'has_elementary_school_within_1km', 'nearest_middle_school_distance',
#        'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
#        'nearest_high_school_distance', 'nearest_high_school_within_1km',
#        'has_high_school_within_1km', 'interest_rate', 'diff_interest_rate',
#        'grid_id', 'recent_deposit', 'contract_ymd', 'apt_deposit_rank',
#        'apt_area_deposit_rank'],
#       dtype='object')

# %%
data['contract_ymd']
# Out:
# 0          2019-06-25
# 1          2020-03-26
# 2          2020-03-28
# 3          2019-07-15
# 4          2019-04-12
#               ...
# 1951395    2024-02-27
# 1951396    2024-03-02
# 1951397    2024-03-16
# 1951398    2024-03-22
# 1951399    2024-03-22
# Name: contract_ymd, Length: 1951400, dtype: object

# %%
data['contract_year_month'] = data['contract_ymd'].str[:4] + data['contract_ymd'].str[5:7]
data['contract_year_month'] = data['contract_year_month'].astype(int)

# %%
data['contract_year_month']
# Out:
# 0          201906
# 1          202003
# 2          202003
# 3          201907
# 4          201904
#             ...
# 1951395    202402
# 1951396    202403
# 1951397    202403
# 1951398    202403
# 1951399    202403
# Name: contract_year_month, Length: 1951400, dtype: int32

# %% [markdown]
# ---

# %% [markdown]
# # V5 추가 EDA

# %%
data['log_grid_id'] = np.log(data['grid_id'])

# %% [markdown]
# # 모델 학습 컬럼 선택

# %%
train_df = data[data['_type']=='train']
test_df = data[data['_type']=='test']

# %%
columns_needed = [
       # 'index', '_type', 'area_price', 'area_m2_price',
       'area_m2', 'contract_year_month', 'contract_day',
       'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
       'deposit', 
       'apt_idx', 
       'area',
       'grid_id', 
       'nearest_subway_distance', 'nearest_subway_idx',
       'num_subway_within_1km', 'category_interchange_within_1km',
       'num_subway_within_500m', 'category_interchange_within_500m',
       'nearest_elementary_school_distance', 'nearest_elementary_school_within_1km',
       'has_elementary_school_within_1km', 'nearest_middle_school_distance',
       'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
       'nearest_high_school_distance', 'nearest_high_school_within_1km',
       'has_high_school_within_1km', 'nearest_park_distance',
       'nearest_park_within_500.0m', 'has_park_within_500.0m',
       'apt_deposit_rank', 'apt_area_deposit_rank', 
       'recent_deposit',
       # 'interest_rate', 'diff_interest_rate'
       ]
columns_needed_test = [
       # 'index', '_type', 'area_price', 'area_m2_price', 'deposit', 
       'area_m2', 'contract_year_month', 'contract_day',
       'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
       'apt_idx', 
       'area',
       'grid_id', 
       'nearest_subway_distance', 'nearest_subway_idx',
       'num_subway_within_1km', 'category_interchange_within_1km',
       'num_subway_within_500m', 'category_interchange_within_500m',
       'nearest_elementary_school_distance', 'nearest_elementary_school_within_1km',
       'has_elementary_school_within_1km', 'nearest_middle_school_distance',
       'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
       'nearest_high_school_distance', 'nearest_high_school_within_1km',
       'has_high_school_within_1km', 'nearest_park_distance',
       'nearest_park_within_500.0m', 'has_park_within_500.0m',
       'apt_deposit_rank', 'apt_area_deposit_rank', 
       'recent_deposit',
       # 'interest_rate', 'diff_interest_rate'
       ]
train_data = train_df[columns_needed]
test_data = test_df[columns_needed_test]

# %% [markdown]
# # Holdout 데이터셋 설정 (예: 2023년 7월부터 12월까지의 데이터)

# %%
holdout_start = 202307
holdout_end = 202312
holdout_data = train_data[
    (train_data['contract_year_month'] >= holdout_start) & (train_data['contract_year_month'] <= holdout_end)]
train_data = train_data[
    ~((train_data['contract_year_month'] >= holdout_start) & (train_data['contract_year_month'] <= holdout_end))]

# %% [markdown]
# # 학습 데이터와 정답 데이터 분리

# %%
X_train = train_data.drop(columns=['deposit'])
y_train = train_data['deposit']
X_holdout = holdout_data.drop(columns=['deposit'])
y_holdout = holdout_data['deposit']
X_test = test_data.copy()

# %% [markdown]
# ## XGBoost 모델 훈련

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(random_state=RANDOM_SEED)
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# 홀드아웃 데이터에 대한 예측
xgb_holdout_pred = xgb_model.predict(X_holdout)

# 홀드아웃 데이터의 MAE 계산
from sklearn.metrics import mean_absolute_error
xgb_holdout_mae = mean_absolute_error(y_holdout, xgb_holdout_pred)

print("Holdout 데이터셋 성능:")
print(f"XGBoost MAE: {xgb_holdout_mae:.2f}")
# Out:
# Holdout 데이터셋 성능:
# XGBoost MAE: 3935.01

# %%
xgb_test_pred = xgb_model.predict(X_test)
sample_submission['deposit'] = xgb_test_pred
# sample_submission.to_csv('v5_aptrank_xgboost.csv', index=False, encoding='utf-8-sig')

# %%
sample_submission.describe()
# Out:
#               index        deposit
# count  150172.00000  150172.000000
# mean    75085.50000   36712.285156
# std     43351.06665   22578.828125
# min         0.00000    3083.683105
# 25%     37542.75000   22274.623535
# 50%     75085.50000   31716.590820
# 75%    112628.25000   45628.979492
# max    150171.00000  627724.687500

# %% [markdown]
# ---

# %%
columns_needed = [
       # 'index', '_type', 'area_price', 'area_m2_price',
       'area_m2', 'contract_year_month', 'contract_day',
       'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age', 'deposit', 
       'apt_idx', 
       'area',
       'grid_id', 
       'nearest_subway_distance', 'nearest_subway_idx',
       'num_subway_within_1km', 'category_interchange_within_1km',
       'num_subway_within_500m', 'category_interchange_within_500m',
       'nearest_elementary_school_distance', 'nearest_elementary_school_within_1km',
       'has_elementary_school_within_1km', 'nearest_middle_school_distance',
       'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
       'nearest_high_school_distance', 'nearest_high_school_within_1km',
       'has_high_school_within_1km', 'nearest_park_distance',
       'nearest_park_within_500.0m', 'has_park_within_500.0m',
       'apt_deposit_rank', 'apt_area_deposit_rank', 
       'recent_deposit',
       # 'interest_rate', 'diff_interest_rate'
       ]
columns_needed_test = [
       # 'index', '_type', 'area_price', 'area_m2_price', 'deposit', 
       'area_m2', 'contract_year_month', 'contract_day',
       'contract_type', 'floor', 'built_year', 'latitude', 'longitude', 'age',
       'apt_idx', 
       'area',
       'grid_id', 
       'nearest_subway_distance', 'nearest_subway_idx',
       'num_subway_within_1km', 'category_interchange_within_1km',
       'num_subway_within_500m', 'category_interchange_within_500m',
       'nearest_elementary_school_distance', 'nearest_elementary_school_within_1km',
       'has_elementary_school_within_1km', 'nearest_middle_school_distance',
       'nearest_middle_school_within_1km', 'has_middle_school_within_1km',
       'nearest_high_school_distance', 'nearest_high_school_within_1km',
       'has_high_school_within_1km', 'nearest_park_distance',
       'nearest_park_within_500.0m', 'has_park_within_500.0m',
       'apt_deposit_rank', 'apt_area_deposit_rank', 
       'recent_deposit',
       # 'interest_rate', 'diff_interest_rate'
       ]
train_data = train_df[columns_needed]
test_data = test_df[columns_needed_test]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
# # 학습에 사용할 특징 열
# feature_columns = [col for col in data.columns if col not in ['deposit', '_type', 'index']]
# 학습 및 테스트 데이터 준비
X_train = train_data.drop(columns=['deposit'])
y_train = train_data['deposit']
X_test = test_data.copy()
# 학습 데이터를 검증용으로 분할
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# XGBoost를 위한 DMatrix 생성
dtrain = xgb.DMatrix(X_train_split, label=y_train_split)
dval = xgb.DMatrix(X_val_split, label=y_val_split)
dtest = xgb.DMatrix(X_test)
# XGBoost 파라미터 설정
params = {
    'objective': 'reg:absoluteerror',
    'eval_metric': 'mae',
    'max_depth': 6,
    'eta': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}
# 모델 학습
evals = [(dtrain, 'train'), (dval, 'eval')]
model = xgb.train(params, dtrain, num_boost_round=500, early_stopping_rounds=50, evals=evals, verbose_eval=10)
# 테스트 세트에 대한 예측
y_pred = model.predict(dtest)
# Out:
# [0]	train-mae:16475.41918	eval-mae:16477.35177
# [10]	train-mae:11206.36541	eval-mae:11209.13301
# [20]	train-mae:8057.94082	eval-mae:8055.91893
# [30]	train-mae:6251.79799	eval-mae:6242.81538
# [40]	train-mae:5266.83937	eval-mae:5254.84143
# [50]	train-mae:4734.17569	eval-mae:4722.86483
# [60]	train-mae:4470.69077	eval-mae:4460.87324
# [70]	train-mae:4344.66280	eval-mae:4336.10638
# [80]	train-mae:4269.98150	eval-mae:4262.95589
# [90]	train-mae:4226.85761	eval-mae:4221.11006
# [100]	train-mae:4197.97323	eval-mae:4192.99396
# [110]	train-mae:4165.09930	eval-mae:4161.31455
# [120]	train-mae:4137.07808	eval-mae:4134.30518
# [130]	train-mae:4117.84754	eval-mae:4116.14675
# [140]	train-mae:4101.21569	eval-mae:4100.29479
# [150]	train-mae:4086.88968	eval-mae:4086.62672
# [160]	train-mae:4075.16847	eval-mae:4075.57195
# [170]	train-mae:4065.15356	eval-mae:4066.17194
# [180]	train-mae:4057.94881	eval-mae:4059.45962
# [190]	train-mae:4048.74761	eval-mae:4050.87739
# [200]	train-mae:4037.76260	eval-mae:4040.12038
# [210]	train-mae:4031.11299	eval-mae:4033.80614
# [220]	train-mae:4024.43999	eval-mae:4027.30237
# [230]	train-mae:4017.79469	eval-mae:4021.05728
# [240]	train-mae:4012.69005	eval-mae:4016.37526
# [250]	train-mae:4006.18118	eval-mae:4010.24072
# [260]	train-mae:4000.86627	eval-mae:4005.24864
# [270]	train-mae:3996.57250	eval-mae:4001.36930
# [280]	train-mae:3990.88810	eval-mae:3995.95646
# [290]	train-mae:3985.01443	eval-mae:3990.28584
# [300]	train-mae:3977.97124	eval-mae:3983.45948
# [310]	train-mae:3972.39819	eval-mae:3978.12227
# [320]	train-mae:3965.39020	eval-mae:3971.39284
# [330]	train-mae:3960.11188	eval-mae:3966.49125
# [340]	train-mae:3956.17749	eval-mae:3962.89142
# [350]	train-mae:3952.81961	eval-mae:3959.80080
# [360]	train-mae:3949.62970	eval-mae:3956.88152
# [370]	train-mae:3944.79537	eval-mae:3952.51935
# [380]	train-mae:3941.65946	eval-mae:3949.76606
# [390]	train-mae:3938.10180	eval-mae:3946.47047
# [400]	train-mae:3934.19697	eval-mae:3943.00110
# [410]	train-mae:3930.80606	eval-mae:3939.86101
# [420]	train-mae:3926.26111	eval-mae:3935.86140
# [430]	train-mae:3921.63380	eval-mae:3931.53927
# [440]	train-mae:3918.45356	eval-mae:3928.69169
# [450]	train-mae:3914.22485	eval-mae:3924.90101
# [460]	train-mae:3910.76329	eval-mae:3921.81094
# [470]	train-mae:3908.19905	eval-mae:3919.51647
# [480]	train-mae:3902.76617	eval-mae:3914.29187
# [490]	train-mae:3899.83511	eval-mae:3911.55972
# [499]	train-mae:3897.01003	eval-mae:3909.01869

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 피처 중요도 추출
feature_importance = model.get_fscore()
# 피처 중요도를 DataFrame으로 변환
importance_df = pd.DataFrame(feature_importance.items(), columns=['Feature', 'Importance'])
# 중요도 순으로 정렬
importance_df = importance_df.sort_values(by='Importance', ascending=False)
# 시각화
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.show()

# %%
# 테스트 데이터를 DMatrix로 변환
dtest = xgb.DMatrix(X_test)

# 예측 수행
xgb_test_pred = model.predict(dtest)

# 결과 저장
sample_submission['deposit'] = xgb_test_pred

# %%
sample_submission.describe()
# Out:
#               index        deposit
# count  150172.00000  150172.000000
# mean    75085.50000   39049.292969
# std     43351.06665   23840.468750
# min         0.00000    3358.489746
# 25%     37542.75000   23207.337891
# 50%     75085.50000   33745.970703
# 75%    112628.25000   48347.227539
# max    150171.00000  366390.093750

# %%
sample_submission.to_csv('v4_xgboost_add(contract_year_month).csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # LightGBM 모델 훈련

# %%
lgb_model = lgb.LGBMRegressor(random_state=RANDOM_SEED)
lgb_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066484 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4146
# [LightGBM] [Info] Number of data points in the train set: 1594362, number of used features: 33
# [LightGBM] [Info] Start training from score 37814.733261
# LGBMRegressor(random_state=42)

# %% [markdown]
# # Holdout 데이터셋에 대한 성능 확인

# %%
lgb_holdout_pred = lgb_model.predict(X_holdout)
lgb_holdout_mae = mean_absolute_error(y_holdout, lgb_holdout_pred)
print("Holdout 데이터셋 성능:")
print(f"LightGBM MAE: {lgb_holdout_mae:.2f}")
# Out:
# Holdout 데이터셋 성능:
# LightGBM MAE: 4006.29

# %% [markdown]
# # Sample Submission 제출하기

# %%
lgb_test_pred = lgb_model.predict(X_test)
sample_submission['deposit'] = lgb_test_pred
# sample_submission.to_csv('v5_aptrank_LGBM.csv', index=False, encoding='utf-8-sig')

# %%
sample_submission.describe()
# Out:
#               index        deposit
# count  150172.00000  150172.000000
# mean    75085.50000   36662.339767
# std     43351.06665   22349.113922
# min         0.00000    4529.476416
# 25%     37542.75000   22481.078127
# 50%     75085.50000   31579.625395
# 75%    112628.25000   45075.800814
# max    150171.00000  729244.015468
